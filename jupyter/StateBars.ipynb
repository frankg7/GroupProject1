# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load
Top_Bottom5 = "Top_Bottom5.csv"

# %%
# Read the Data
Top_Bottom5_data = pd.read_csv("Top_Bottom5.csv")

# %%
Top_Bottom5_data.head()
# Out:
#      Type                 State   Rate
# 0  Breast         New Hampshire  143.9
# 1  Breast  District of Columbia  139.7
# 2  Breast         Massachusetts  137.6
# 3  Breast          Rhode Island  135.3
# 4  Breast          South Dakota  134.3

# %%
Top_Bottom5_data.count()
# Out:
# Type     40
# State    40
# Rate     40
# dtype: int64

# %%
# Create plots for each cancer state average rate and plot against superfund site locations
# rate per 100,000
breast_rate = [
143.9,
139.7,
137.6,
135.3,
134.3,
114.7,
112.9,
112.6,
111.7,
93.2,
]

breast_index = ['New Hampshire',
'District of Columbia',
'Massachusetts',
'Rhode Island',
'South Dakota',
'Arkansas',
'Arizona',
'Wyoming',
'Texas',
'Puerto Rico'
]

superfund_breast = [
22,
1,
40,
13,
4,
17,
14,
3,
69,
25
]

breast_df = pd.DataFrame({'Rates per 100,000': breast_rate, 'Superfund Sites': superfund_breast }, index=breast_index)
ax = breast_df.plot.bar(align='edge', rot=45)
ax.set_title('Breast Cancer', color='C6')
plt.savefig("Breast_Cancer_BarPlot.png")

# %%
# load the colon cancer data
c_rate = [
48.4,
47,
45.7,
43.9,
43.6,
35.9,
34.8,
33.8,
33.6,
33.3
]

Colon_index = [
'Mississippi', 
'West Virginia',
'North Dakota',
'Illinois',
'Arkansas',
'Rhode Island',
'Oregon',
'Colorado',
'Arizona',
'Wyoming',
]

superfund_colon = [
14,
13,
2,
69,
17,
13,
19,
24,
14,
3
]

colon_df = pd.DataFrame({'Rate per 100,000': c_rate,'Superfund Sites': superfund_colon }, index=Colon_index)
colon_ax = colon_df.plot.bar(align='edge', rot=45)
colon_ax.set_title('Colon Cancer', color='C0')
plt.savefig("Colon_Cancer_Bar_Plot.png")

# %%
# load the lung cancer data
l_rate = [
80.3,
78,
75.7,
75,
74.2,
50.7,
49.3,
44.5,
43.3,
17.7
]

lung_index = [
'West Virginia',
'Arkansas',
'Tennessee',
'Mississippi',
'Missouri',
'Idaho',
'Arizona',
'Wyoming',
'Colorado',
'Puerto Rico'
]

superfund_lung = [
13,
17,
29,
14,
39,
12,
14,
3,
24,
25
]

lung_df = pd.DataFrame({'Rate per 100,000': l_rate,'Superfund Sites': superfund_lung}, index=lung_index)
lung_ax = lung_df.plot.bar(align='edge',rot=45)
lung_ax.set_title('Lung Cancer', color='C1')
plt.savefig("Lung_Cancer_BarPlot.png")

# %%
# load the prostate cancer data
p_rate = [
146.6,
143.5,
136.1,
131.7,
130.6,
93.6,
92.7,
92,
79.6,
78.6
]

prostate_index = [
'Puerto Rico',
'District of Columbia',
'Delaware',
'New York',
'Mississippi',
'Maine',
'Indiana',
'Vermont',
'Alaska',
'Arizona',
]

superfund_prostate = [
25,
1,
23,
120,
14,
16,
53,
14,
10,
14
]

prostate_df = pd.DataFrame({'Rate per 100,000': p_rate, 'Superfund Sites': superfund_prostate}, index=prostate_index)
prostate_ax = prostate_df.plot.bar(align='edge', rot=45)
prostate_ax.set_title('Prostate Cancer', color='C2')
plt.savefig("Prostate_Cancer_Bar_Plot.png")
