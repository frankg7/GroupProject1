# %%
import glob
import pandas as pd
import numpy as np

csvfiles = glob.glob("Resources/*.csv")

# %%
file = pd.read_csv("Resources/test.csv")

# %%
df = pd.DataFrame(file)
state_value = df.loc[8][0]
state,b=state_value.split("(")

type = df.loc[1][0]
cancer_type,years = type.split(",")

df.insert(0,'State',state)
df.insert(1,'Cancer Type', cancer_type)
df.insert(2,'Years', years)

df.columns = ['State','Cancer Type','Years','County','FIPS','Objective','Age-Adjusted Incident Rate','Lower 95%','Upper 95%','Average Annual Count','Recent Trend','Recent 5-year Trend','Lower 95% Confidence Interval','Upper 95% Confidence Interval']
#new_df = df.dropna()

new_df.head(10)
# Out:
#       State Cancer Type       Years                County   FIPS  \
# 7   Alabama      Breast   2011-2015                County   FIPS
# 8   Alabama      Breast   2011-2015         Alabama(6,10)   1000
# 9   Alabama      Breast   2011-2015  US (SEER+NPCR)(1,10)      0
# 10  Alabama      Breast   2011-2015  Pickens County(6,10)   1107
# 11  Alabama      Breast   2011-2015  Conecuh County(6,10)   1035
# 12  Alabama      Breast   2011-2015     Bibb County(6,10)   1007
# 13  Alabama      Breast   2011-2015  Autauga County(6,10)   1001
# 14  Alabama      Breast   2011-2015   Butler County(6,10)   1013
# 15  Alabama      Breast   2011-2015  Bullock County(6,10)   1011
# 16  Alabama      Breast   2011-2015   Greene County(6,10)   1063
#
#                                Objective  \
# 7   Met Healthy People Objective of ***?
# 8                                    ***
# 9                                    ***
# 10                                   ***
# ...
