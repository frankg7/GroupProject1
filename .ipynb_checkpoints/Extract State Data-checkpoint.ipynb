# %%
import glob
import pandas as pd
import numpy as np
import string

csvfiles = glob.glob("Resources/*.csv")

# %%
count = 0

for file in csvfiles:
    print("Processing: " + file.upper())
    read_file = pd.read_csv(file, encoding='latin1')
    df = pd.DataFrame(read_file)
    df = df.iloc[1:]
    ctype = df.loc[1][0]
    cancer_type,years = ctype.split(",")
    df = df.iloc[7:]
    df.dropna()
    df.columns = ['County','FIPS','Met Health Obj','Age-Adjusted Incident Rate','Lower 95% Confidence Interval','Upper 95% Confidence Interval','Average Annual Count','Recent Trend','Recent 5-Year Trend in Incidence Rates','Lower 95% Confidence Interval','Upper 95% Confidence Interval']
    df['Cancer Type'] = cancer_type
    df['Years'] = years
    state = df.loc[8][0]
    state_value,years = state.split("(")
    #print(state_value)
    df['State'] = state_value
    
    if count == 0:
        dfa = df
        count = 1
    elif count > 0:
        result = dfa.append(df)
        dfa = result

new = dfa.dropna(subset=['FIPS'])
new.to_csv("combined_data.csv")
new.head()
# Out:
# Processing: RESOURCES\ALABAMA_BREAST.CSV
# Processing: RESOURCES\ALABAMA_COLON.CSV
# Processing: RESOURCES\ALABAMA_LUNG.CSV
# Processing: RESOURCES\ALASKA_COLON.CSV
# Processing: RESOURCES\ALASKA_LUNG.CSV
# Processing: RESOURCES\ARIZONA_BREAST.CSV
# Processing: RESOURCES\ARIZONA_COLON.CSV
# Processing: RESOURCES\ARIZONA_LUNG.CSV
# Processing: RESOURCES\ARKANSAS_BREAST.CSV
# Processing: RESOURCES\ARKANSAS_COLON.CSV
# Processing: RESOURCES\ARKANSAS_LUNG.CSV
# Processing: RESOURCES\CALIFORNIA_BREAST.CSV
# Processing: RESOURCES\CALIFORNIA_COLON.CSV
# Processing: RESOURCES\CALIFORNIA_LUNG.CSV
# Processing: RESOURCES\COLORADO_BREAST.CSV
# Processing: RESOURCES\COLORADO_COLON.CSV
# Processing: RESOURCES\COLORADO_LUNG.CSV
# Processing: RESOURCES\CONNECTICUT_BREAST.CSV
# Processing: RESOURCES\CONNECTICUT_COLON.CSV
# Processing: RESOURCES\CONNECTICUT_LUNG.CSV
# Processing: RESOURCES\DC_LUNG.CSV
# Processing: RESOURCES\DELAWARE_BREAST.CSV
# Processing: RESOURCES\DELAWARE_COLON.CSV
# Processing: RESOURCES\DELAWARE_LUNG.CSV
# Processing: RESOURCES\DISTRICT_OF_COLUMBIA_COLON.CSV
# Processing: RESOURCES\FLORIDA_BREAST.CSV
# Processing: RESOURCES\FLORIDA_COLON.CSV
# Processing: RESOURCES\FLORIDA_LUNG.CSV
# Processing: RESOURCES\GEORGIA_BREAST.CSV
# Processing: RESOURCES\GEORGIA_COLON.CSV
# Processing: RESOURCES\GEORGIA_LUNG.CSV
# Processing: RESOURCES\HAWAII_BREAST.CSV
# Processing: RESOURCES\HAWAII_COLON.CSV
# Processing: RESOURCES\HAWAII_LUN.CSV
# Processing: RESOURCES\IDAHO_BREAST.CSV
# Processing: RESOURCES\IDAHO_COLON.CSV
# Processing: RESOURCES\IDAHO_LUNG.CSV
# Processing: RESOURCES\ILLINOIS_BREAST.CSV
# Processing: RESOURCES\ILLINOIS_COLON.CSV
# Processing: RESOURCES\ILLINOIS_LUNG.CSV
# Processing: RESOURCES\INDIANA_BREAST.CSV
# Processing: RESOURCES\INDIANA_COLON.CSV
# Processing: RESOURCES\INDIANA_LUNG.CSV
# Processing: RESOURCES\IOWA_BREAST.CSV
# Processing: RESOURCES\IOWA_COLON.CSV
# Processing: RESOURCES\IOWA_LUNG.CSV
# Processing: RESOURCES\KANSAS_BREAST_NULL.CSV
# Processing: RESOURCES\KANSAS_COLON.CSV
# Processing: RESOURCES\KANSAS_LUNG.CSV
# Processing: RESOURCES\KENTUCKY_BREAST.CSV
# Processing: RESOURCES\KENTUCKY_COLON.CSV
# Processing: RESOURCES\KENTUCKY_LUNG.CSV
# Processing: RESOURCES\LOUISANA_COLON.CSV
# Processing: RESOURCES\LOUISIANA_BREAST.CSV
# Processing: RESOURCES\LOUISIANA_LUNG.CSV
# Processing: RESOURCES\MAINE_BREAST.CSV
# Processing: RESOURCES\MAINE_COLON.CSV
# Processing: RESOURCES\MAINE_LUNG.CSV
# Processing: RESOURCES\MARYLAND_BREAST.CSV
# Processing: RESOURCES\MARYLAND_COLON.CSV
# Processing: RESOURCES\MARYLAND_LUNG.CSV
# Processing: RESOURCES\MASSACHUSETTS_BREAST.CSV
# Processing: RESOURCES\MASSACHUSETTS_COLON.CSV
# Processing: RESOURCES\MASSACHUSETTS_LUNG.CSV
# Processing: RESOURCES\MICHIGAN_BREAST.CSV
# Processing: RESOURCES\MICHIGAN_COLON.CSV
# Processing: RESOURCES\MICHIGAN_LUNG.CSV
# Processing: RESOURCES\MINNESOTA_BREAST_NULL.CSV
# Processing: RESOURCES\MINNESOTA_COLON.CSV
# Processing: RESOURCES\MINNESOTA_LUNG.CSV
# Processing: RESOURCES\MISSISSIPPI_BREAST.CSV
# Processing: RESOURCES\MISSISSIPPI_COLON.CSV
# Processing: RESOURCES\MISSISSIPPI_LUNG.CSV
# Processing: RESOURCES\MISSOURI_BREAST.CSV
# Processing: RESOURCES\MISSOURI_COLON.CSV
# Processing: RESOURCES\MISSOURI_LUNG.CSV
# Processing: RESOURCES\MONTANA_BREAST.CSV
# Processing: RESOURCES\MONTANA_COLON.CSV
# Processing: RESOURCES\MONTANA_LUNG.CSV
# Processing: RESOURCES\NEBRASKA_BREAST.CSV
# Processing: RESOURCES\NEBRASKA_LUNG.CSV
# Processing: RESOURCES\NEBRESKA_COLON.CSV
# Processing: RESOURCES\NEVADA_BREAST_NULL.CSV
# Processing: RESOURCES\NEVADA_COLON.CSV
# Processing: RESOURCES\NEVADA_LUNG.CSV
# Processing: RESOURCES\NEW-HAMPSHIRE_COLON.CSV
# Processing: RESOURCES\NEW_HAMPSHIRE_BREAST.CSV
# Processing: RESOURCES\NEW_HAMPSHIRE_LUNG.CSV
# Processing: RESOURCES\NEW_JERSEY_BREAST.CSV
# Processing: RESOURCES\NEW_JERSEY_COLON.CSV
# Processing: RESOURCES\NEW_JERSEY_LUNG.CSV
# Processing: RESOURCES\NEW_MEXICO_BREAST.CSV
# Processing: RESOURCES\NEW_MEXICO_COLON.CSV
# Processing: RESOURCES\NEW_MEXICO_LUNG.CSV
# Processing: RESOURCES\NEW_YORK_BREAST.CSV
# Processing: RESOURCES\NEW_YORK_COLON.CSV
# Processing: RESOURCES\NEW_YORK_LUNG.CSV
# Processing: RESOURCES\NORTH_CAROLINA_BREAST.CSV
# Processing: RESOURCES\NORTH_CAROLINA_COLON.CSV
# Processing: RESOURCES\NORTH_CAROLINA_LUNG.CSV
# Processing: RESOURCES\NORTH_DAKOTA_BREAST.CSV
# Processing: RESOURCES\NORTH_DAKOTA_COLON.CSV
# Processing: RESOURCES\NORTH_DAKOTA_LUNG.CSV
# Processing: RESOURCES\OHIO_BREAST.CSV
# Processing: RESOURCES\OHIO_COLON.CSV
# Processing: RESOURCES\OHIO_LUNG.CSV
# Processing: RESOURCES\OKLAHOMA_BREAST.CSV
# Processing: RESOURCES\OKLAHOMA_COLON.CSV
# Processing: RESOURCES\OKLAHOMA_LUNG.CSV
# Processing: RESOURCES\OREGON_BREAST.CSV
# Processing: RESOURCES\OREGON_COLON.CSV
# Processing: RESOURCES\OREGON_LUNG.CSV
# Processing: RESOURCES\PENNSYLVANIA_BREAST.CSV
# Processing: RESOURCES\PENNSYLVANIA_COLON.CSV
# Processing: RESOURCES\PENNSYLVANIA_LUNG.CSV
# Processing: RESOURCES\PUERTO_RICO_BREAST.CSV
# Processing: RESOURCES\PUERTO_RICO_COLON.CSV
# Processing: RESOURCES\PUERTO_RICO_LUNG.CSV
# Processing: RESOURCES\RHODE_ISLAND_BREAST.CSV
# Processing: RESOURCES\RHODE_ISLAND_COLON.CSV
# Processing: RESOURCES\RHODE_ISLAND_LUNG.CSV
# Processing: RESOURCES\SOUTH_CAROLINA_BREAST.CSV
# Processing: RESOURCES\SOUTH_CAROLINA_COLON.CSV
# Processing: RESOURCES\SOUTH_CAROLINA_LUNG.CSV
# Processing: RESOURCES\SOUTH_DAKOTA_BREAST.CSV
# Processing: RESOURCES\SOUTH_DAKOTA_COLON.CSV
# Processing: RESOURCES\SOUTH_DAKOTA_LUNG.CSV
# Processing: RESOURCES\TENNESSEE_BREAST.CSV
# Processing: RESOURCES\TENNESSEE_COLON.CSV
# Processing: RESOURCES\TENNESSEE_LUNG.CSV
# Processing: RESOURCES\TEXAS_BREAST.CSV
# Processing: RESOURCES\TEXAS_COLON.CSV
# Processing: RESOURCES\TEXAS_LUNG.CSV
# Processing: RESOURCES\UTAH_BREAST.CSV
# Processing: RESOURCES\UTAH_COLON.CSV
# Processing: RESOURCES\UTAH_LUNG.CSV
# Processing: RESOURCES\VERMONT_BREAST.CSV
# Processing: RESOURCES\VERMONT_COLON.CSV
# Processing: RESOURCES\VERMONT_LUNG.CSV
# Processing: RESOURCES\VIRGINIA_BREAST.CSV
# Processing: RESOURCES\VIRGINIA_COLON.CSV
# Processing: RESOURCES\VIRGINIA_LUNG.CSV
# Processing: RESOURCES\WASHINGTON_BREAST.CSV
# Processing: RESOURCES\WASHINGTON_COLON.CSV
# Processing: RESOURCES\WASHINGTON_LUNG.CSV
# Processing: RESOURCES\WASH_DC_BREAST.CSV
# Processing: RESOURCES\WEST_VIRGINA_COLON.CSV
# Processing: RESOURCES\WEST_VIRGINIA_BREAST.CSV
# Processing: RESOURCES\WEST_VIRGINIA_LUNG.CSV
# Processing: RESOURCES\WISCONSIN_BREAST.CSV
# Processing: RESOURCES\WISCONSIN_COLON.CSV
# Processing: RESOURCES\WISCONSIN_LUNG.CSV
# Processing: RESOURCES\WYOMING_BREAST.CSV
# Processing: RESOURCES\WYOMING_COLON.CSV
# Processing: RESOURCES\WYOMING_LUNG.CSV
#                   County  FIPS Met Health Obj Age-Adjusted Incident Rate  \
# 8          Alabama(6,10)  1000            ***                      120.9
# 9   US (SEER+NPCR)(1,10)     0            ***                      124.7
# 10  Pickens County(6,10)  1107            ***                      162.1
# 11  Conecuh County(6,10)  1035            ***                      162.1
# 12     Bibb County(6,10)  1007            ***                      157.9
#
#    Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 8                          119.1                         122.7
# 9                          124.4                         124.9
# 10                         130.6                         199.2
# 11                         123.4                         209.5
# 12                         128.2                         192.7
#
#    Average Annual Count Recent Trend Recent 5-Year Trend in Incidence Rates  \
# 8                  3645       rising                                      1
# 9                234445       stable                                    0.2
# 10                   20       stable                                    4.8
# 11                   14       stable                                     -6
# 12                   21       stable                                   -3.8
#
#    Lower 95% Confidence Interval Upper 95% Confidence Interval Cancer Type  \
# 8                            0.2                           1.7      Breast
# 9                           -0.2                           0.6      Breast
# 10                         -29.7                          56.4      Breast
# 11                           -18                           7.9      Breast
# 12                         -39.6                          53.3      Breast
#
#          Years    State
# 8    2011-2015  Alabama
# 9    2011-2015  Alabama
# 10   2011-2015  Alabama
# 11   2011-2015  Alabama
# 12   2011-2015  Alabama
